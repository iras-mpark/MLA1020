# %% [markdown]
# <a href="https://colab.research.google.com/github/iras-mpark/MLA1020/blob/main/week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to Reinforcement Learning

# %%
from dataclasses import dataclass
from typing import Any


@dataclass(frozen=True)
class Step:
    action: Any
    prob: float  # New: the probability that we ended up here
    reward: float
    state: Any
class MDP:
    def start_state(self) -> Any:
        raise NotImplementedError

    def successors(self, state: Any) -> list[Step]:
        raise NotImplementedError

    def is_end(self, state: Any) -> bool:
        raise NotImplementedError
    def discount(self) -> float:
        raise NotImplementedError
class FlakyTramMDP(MDP):
    def __init__(self, num_locs: int, failure_prob: float):
        self.num_locs = num_locs
        self.failure_prob = failure_prob
    def start_state(self) -> Any:
        return 1

    def successors(self, state: Any) -> list[Step]:
        successors = []
        # Walk
        if state + 1 <= self.num_locs:
            successors.append(Step(action="walk", prob=1, reward=-1, state=state + 1))
        # Tram
        if 2 * state <= self.num_locs:
            # Success: move to desired state
            successors.append(Step(action="tram", prob=1 - self.failure_prob, reward=-2, state=2 * state))
            # Failure: stay in the same state
            successors.append(Step(action="tram", prob=self.failure_prob, reward=-2, state=state))
        return successors
    def is_end(self, state: Any) -> bool:
        return state == self.num_locs
    def discount(self) -> float:
        # No discounting for now
        return 1

# %% [markdown]
# #### Environment

# %%
import numpy as np

mdp = FlakyTramMDP(num_locs=10, failure_prob=0.4)
np.random.seed(1)

# %% [markdown]
# #### Agent

# %%
def tram_if_possible_policy(mdp: MDP, state: int) -> str:
    """Need the MDP to know the number of locations to make sure we can take the tram."""
    if state * 2 <= mdp.num_locs:
        return "tram"
    else:
        return "walk"

# %%
from typing import Callable
Policy = Callable[[Any], Any]

class RLAlgorithm:
    """
    Abstract class for an RL algorithm, which does two things:
    1. Sends actions to the environment
    2. Incorporates feedback from the environment
    """
    def get_action(self, state: Any) -> Any:
        raise NotImplementedError
    def incorporate_feedback(self, state: Any, action: Any, reward: Any, next_state: Any, is_end: bool) -> None:
        raise NotImplementedError

class StaticAgent(RLAlgorithm):
    def __init__(self, policy: Policy):
        self.policy = policy
    def get_action(self, state: Any) -> Any:
        return self.policy(state)
    def incorporate_feedback(self, state: Any, action: Any, reward: Any, next_state: Any, is_end: bool) -> None:
        # Setup Reward Feedback Loigic
        pass

# %%
from functools import partial

policy = partial(tram_if_possible_policy, mdp)
rl = StaticAgent(policy=policy)
rl.get_action(state=1)

print(f"Action taken: {action}")
# Out:
# Action taken: tram

# %% [markdown]
# #### Rollout

# %%
def sample_transition(mdp: MDP, state: Any, action: Any) -> Step:
    """
    Samples a transition from the MDP: samples s' with probability T(s, a, s').
    Returns:
    - reward: the reward for the transition
    - next_state: the next state
    - is_end: whether the next state is an end state
    """
    # Get successors given (state, action)
    successors = [successor for successor in mdp.successors(state) if successor.action == action]
    if len(successors) == 0:
        raise ValueError(f"No successors found for state {state} and action {action}")
    # Sample a successor based on its probabilities
    probs = [successor.prob for successor in successors]
    choice = np.random.choice(len(successors), p=probs)
    step = successors[choice]
    return step

# %%
def compute_utility(steps: list[Step], discount: float) -> float:
    """Computes the utility (discounted sum of rewards) of a rollout."""
    rewards = [step.reward * discount ** i for i, step in enumerate(steps)]
    utility = sum(rewards)
    return utility

# %%
class Rollout:
    """Represents a rollout of an MDP (sequence of actions that produces a utility)."""
    steps: list[Step]
    discount: float
    utility: float  # Discounted sum of rewards
    def __init__(self, steps: list[Step], discount: float):
        self.steps = steps
        self.discount = discount
        self.utility = compute_utility(steps, discount)

# %%
def simulate(mdp: MDP, rl: RLAlgorithm, num_trials: int) -> float:
    """
    Runs the RL algorithm on the MDP.
    Return the mean utility of the rollouts.
    """
    utilities = []
    # Repeat multiple times
    for trial in range(num_trials):
        # Environment state
        state = mdp.start_state()
        steps = []
        while not mdp.is_end(state):
            # Agent sends action to environment
            action = rl.get_action(state)
            # Environment sends reward and next state to agent
            step = sample_transition(mdp, state, action)
            rl.incorporate_feedback(state, action, step.reward, step.state, mdp.is_end(step.state))
            steps.append(step)
            state = step.state
        # Compute utility of this rollout
        rollout = Rollout(steps=steps, discount=mdp.discount())
        utilities.append(rollout.utility)
    mean_utility = np.mean(utilities).item()
    return mean_utility

# %%
LEADERBOARD = {}  # method -> value

def update_leaderboard(method: str, value: float) -> dict[str, float]:
    LEADERBOARD[method] = value
    return LEADERBOARD

# %%
value = simulate(mdp, rl, num_trials=10)
print(f"Value from Rollout: {value}")

leaderboard = update_leaderboard("tram_if_possible_policy", value)

print(leaderboard)
# Out:
# Value from Rollout: -11.6
# {'tram_if_possible_policy': -11.6}

# %% [markdown]
# # Model-based RL

# %%
# Tram 탈 수 있으면 확률적으로 tram을 타고, 그 외에는 walk를 항상 선택하는 policy

def walk_tram_policy(num_locs: int, state: Any) -> Any:
    """Chooses a random valid action."""
    if 2 * state <= num_locs:
        # Can take the tram
        return np.random.choice(["walk", "tram"]).item()
    else:
        # Can only walk
        return "walk"

# %%
def try_out_exploration_policy(exploration_policy: Policy):
    state=1
    action = exploration_policy(state)
    print(f"Action taken: {action}, at State {state}")
    action = exploration_policy(state)
    print(f"Action taken: {action}, at State {state}")
    action = exploration_policy(state)
    print(f"Action taken: {action}, at State {state}")

    state=6
    action = exploration_policy(state=6)
    print(f"Action taken: {action}, at State {state}")

# %%
exploration_policy = partial(walk_tram_policy, mdp.num_locs)
try_out_exploration_policy(exploration_policy)
# Out:
# Action taken: walk, at State 1
# Action taken: tram, at State 1
# Action taken: tram, at State 1
# Action taken: walk, at State 6

# %% [markdown]
# #### Exploration으로 MDP를 재구축 하자

# %%
from collections import defaultdict
import numpy as np
from typing import Any, List, Dict, Tuple

class Step:
    def __init__(self, action: Any, prob: float, reward: float, state: Any):
        self.action = action
        self.prob = prob
        self.reward = reward
        self.state = state

    def __repr__(self):
        return f"Step(action={self.action}, prob={self.prob}, reward={self.reward}, state={self.state})"

class EstimatedMDP:
    """An MDP whose start state, rewards, transitions, and is_end are learned from feedback during RL."""
    def __init__(self, discount: float):
        self.start_state_ = None
        self.rewards = defaultdict(float)  # (state, action, state') -> reward
        self.transitions = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))  # state -> action -> state' -> count
        self.end_states = set()
        self.discount_ = discount

    def start_state(self) -> Any:
        return self.start_state_

    def successors(self, state: Any) -> List[Step]:
        """Compute successors based on the transition counts and rewards."""
        successors = []
        for action, next_state_counts in self.transitions[state].items():
            total_count = sum(next_state_counts.values())
            for next_state, count in next_state_counts.items():
                prob = count / total_count
                reward = self.rewards[(state, action, next_state)]
                step = Step(action=action, prob=prob, reward=reward, state=next_state)
                successors.append(step)
        return successors

    def is_end(self, state: Any) -> bool:
        return state in self.end_states

    def discount(self) -> float:
        return self.discount_

    def incorporate_feedback(self, state: Any, action: Any, reward: Any, next_state: Any, is_end: bool) -> None:
        if self.start_state_ is None:
            self.start_state_ = state
        self.rewards[(state, action, next_state)] = reward
        self.transitions[state][action][next_state] += 1
        if is_end:
            self.end_states.add(next_state)

    def asdict(self) -> Dict[str, Any]:
        return {
            "start_state_": self.start_state_,
            "rewards": self.rewards,
            "transition_counts": self.transitions,
            "end_states": list(self.end_states),
        }

def get_states(mdp: EstimatedMDP) -> List[Any]:
    states = set()
    def recurse(state: Any):
        if state in states: return
        states.add(state)
        for step in mdp.successors(state):
            recurse(step.state)
    if mdp.start_state() is not None: recurse(mdp.start_state())
    return list(states)

def get_initial_values(mdp: EstimatedMDP) -> Dict[Any, float]:
    states = get_states(mdp)
    return {state: 0 if mdp.is_end(state) else -100 for state in states}

def get_action_successors(mdp: EstimatedMDP, state: Any) -> Dict[str, List[Step]]:
    successors = mdp.successors(state)
    action_to_successors = defaultdict(list)
    for step in successors:
        action_to_successors[step.action].append(step)
    return action_to_successors

def compute_q_value(successors: List[Step], discount: float, values: Dict[Any, float]) -> float:
    return sum(step.prob * (step.reward + discount * values.get(step.state, -100)) for step in successors)


def compute_distance(values: dict[Any, float], new_values: dict[Any, float]) -> float:
    """Compute the distance between two sets of values."""
    distances = [abs(values[state] - new_values[state]) for state in values]
    max_distance = max(distances)
    return max_distance

@dataclass(frozen=True)
class ValueIterationResult:
    values: dict[Any, float]  # state -> value of that state
    pi: dict[Any, Any]  # state -> action for that state
    distances: list[float]  # iteration -> change in value that iteration
def value_iteration(mdp: MDP, max_iters: int = 100, tolerance: float = 1e-5) -> ValueIterationResult:
    """
    Compute the value of the optimal policy.
    Returns:
    - values: dict[Any, float]: state -> optimal value of that state
    - pi: dict[Any, Any]: state -> optimal action for that state
    - distances: list[float]: distance between values and new values at each iteration
    """
    # Initialize values of each state
    values = get_initial_values(mdp)
    # Initialize the policy (state -> action)
    pi = {state: None for state in values}
    distances = []
    for iter in range(max_iters):
        new_values = {}  # state -> V_iter(state)
        for state in values:
            if mdp.is_end(state):
                new_values[state] = 0
                continue
            new_values[state], pi[state] = value_iteration_for_state(mdp, state, values)
        # Check for convergence
        distance = compute_distance(values, new_values)
        distances.append(distance)
        if distance < tolerance:
            break
        # Update values to the next iteration
        values = new_values
    return ValueIterationResult(values=values, pi=pi, distances=distances)
def value_iteration_for_state(mdp: MDP, state: Any, values: dict[Any, float]) -> tuple[float, Any]:
    """Compute optimal value V`*`(state) and optimal policy π`*`(state)."""
    # V^* = max_a Q(s, a, V^*)
    # For each action, compute its Q-value
    actions = []
    q_values = []
    # Look at all actions from state
    for action, successors in get_action_successors(mdp, state).items():
        actions.append(action)
        q_values.append(compute_q_value(successors, mdp.discount(), values))
    # Take the best action
    value = np.max(q_values)
    action = actions[np.argmax(q_values)]
    return value, action

class ModelBasedValueIteration:
    def __init__(self, exploration_policy: Any, discount: float):
        self.exploration_policy = exploration_policy
        self.exploitation_policy = None
        self.mdp = EstimatedMDP(discount=discount)

    def run_value_iteration(self):
        result = value_iteration(self.mdp)
        self.exploitation_policy = result.pi

    def get_action(self, state: Any) -> Any:
        if self.exploitation_policy is None or state not in self.exploitation_policy: return self.exploration_policy(state)
        return self.exploitation_policy[state]

    def incorporate_feedback(self, state, action, reward, next_state, is_end):
        self.mdp.incorporate_feedback(state, action, reward, next_state, is_end)

# %%
def compare_mdps(true_mdp: MDP, estimated_mdp: MDP):
    print(f"True MDP Start State: {true_mdp.start_state()}")
    print(f"Estimated MDP Start State: {estimated_mdp.start_state()}")
    print(f"True Successors: {true_mdp.successors(state=1)}")
    print(f"Estimated Successors: {estimated_mdp.successors(state=1)}")
    print(f"True End State (is_end(state=9)?: {true_mdp.is_end(state=9)}")
    print(f"Estimated End State (is_end(state=9)?: {estimated_mdp.is_end(state=9)}")

# %%
rl = ModelBasedValueIteration(exploration_policy=exploration_policy, discount=1)

value = simulate(mdp, rl, num_trials=10)
print(f"Average Value from Rollout: {value}")
leaderboard = update_leaderboard("model_based_value_iteration.explore", value)
print(f"Update to Leaderboard: {leaderboard}")

print("\n---------- Compare True MDP vs. Estimated MDP ----------")
compare_mdps(mdp, rl.mdp)
# Out:
# Average Value from Rollout: -10.7
# Update to Leaderboard: {'tram_if_possible_policy': -11.6, 'model_based_value_iteration.explore': -10.7}
#
# ---------- Compare True MDP vs. Estimated MDP ----------
# True MDP Start State: 1
# Estimated MDP Start State: 1
# True Successors: [Step(action=walk, prob=1, reward=-1, state=2), Step(action=tram, prob=0.6, reward=-2, state=2), Step(action=tram, prob=0.4, reward=-2, state=1)]
# Estimated Successors: [Step(action=tram, prob=0.4444444444444444, reward=-2, state=1), Step(action=tram, prob=0.5555555555555556, reward=-2, state=2), Step(action=walk, prob=1.0, reward=-1, state=2)]
# True End State (is_end(state=9)?: False
# Estimated End State (is_end(state=9)?: False

# %% [markdown]
# #### Value iteration을 실행하자

# %%
def compare_policies(true_policy: Dict[Any, Any], estimated_policy: Dict[Any, Any]):
    """Compares the policies from the true MDP and the estimated MDP."""
    print("----------- Comparing Policies -----------")
    print("True Policy:")
    for state in sorted(true_policy.keys()):
        print(f"State {state}: Action {true_policy[state]}")

    print("\nEstimated Policy:")
    for state in sorted(estimated_policy.keys()):
        action = estimated_policy.get(state, None)
        print(f"State {state}: Action {action if action is not None else 'No action defined'}")

# Example usage of compare_policies
rl.run_value_iteration()  # Ensure value iteration has been run to populate the exploitation policy

true_policy = value_iteration(mdp).pi  # Obtain the policy from the true MDP
estimated_policy = rl.exploitation_policy  # The policy from the estimated MDP

compare_policies(true_policy, estimated_policy)
# Out:
# ----------- Comparing Policies -----------
# True Policy:
# State 1: Action walk
# State 2: Action walk
# State 3: Action walk
# State 4: Action walk
# State 5: Action tram
# State 6: Action walk
# State 7: Action walk
# State 8: Action walk
# State 9: Action walk
# State 10: Action None
#
# Estimated Policy:
# State 1: Action walk
# State 2: Action walk
# State 3: Action walk
# State 4: Action tram
# State 5: Action walk
# State 6: Action walk
# State 7: Action walk
# State 8: Action walk
# State 9: Action walk
# State 10: Action No action defined

# %% [markdown]
# #### Model-free RL

# %%
class ModelFreeMonteCarlo(RLAlgorithm):
    def __init__(self, exploration_policy: Policy, epsilon: float, discount: float):
        self.exploration_policy = exploration_policy
        self.epsilon = epsilon
        self.discount = discount
        self.sum_utilities = defaultdict(lambda: defaultdict(float))  # state -> action -> sum of utility from (state, action)
        self.counts = defaultdict(lambda: defaultdict(int))  # state -> action -> visitation count
        self.start_state = None
        self.rollout: list[Step] = []

    def get_action(self, state: Any) -> Any:
        if len(self.counts[state]) == 0:
            # If no actions have been tried yet, choose a random action
            action = self.exploration_policy(state)
            print(f"State {state}: Choosing random action {action} (initial exploration)")
            return action

        # Do epsilon-greedy
        if np.random.random() < self.epsilon:
            action = self.exploration_policy(state)
            print(f"State {state}: Choosing random action {action} (epsilon-greedy)")
            return action
        else:
            action = self.pi(state)
            print(f"State {state}: Choosing best action {action} (based on Q-values)")
            return action

    def pi(self, state: Any) -> Any:
        """Return the policy corresponding to the current Q-values."""
        actions = list(self.counts[state].keys())
        q_values = [self.Q(state, action) for action in actions]
        action = actions[np.argmax(q_values).item()]
        return action

    def Q(self, state: Any, action: Any) -> float:
        """Compute the estimated Q-values Q(state, action) using the running sums and counts."""
        sum_utility = self.sum_utilities[state][action]
        count = self.counts[state][action]
        value = sum_utility / count if count > 0 else 0.0
        return value

    def incorporate_feedback(self, state: Any, action: Any, reward: Any, next_state: Any, is_end: bool) -> None:
        print(f"Incorporating feedback: state={state}, action={action}, reward={reward}, next_state={next_state}, is_end={is_end}")

        # Add this piece of feedback (state, action, reward, next_state) to the history
        if self.start_state is None:
            self.start_state = state

        self.rollout.append(Step(action=action, prob=1, reward=reward, state=next_state))

        # At the end of the episode, update the statistics needed for computing Q-values
        if is_end:
            print("End of episode reached.")
            utilities = [0] * (len(self.rollout) + 1)
            # Walk backwards and compute the utilities for each step
            for i, step in reversed(list(enumerate(self.rollout))):
                state = self.start_state if i == 0 else self.rollout[i - 1].state
                utilities[i] = step.reward + self.discount * utilities[i + 1]

                # Update the running sums
                self.sum_utilities[state][step.action] += utilities[i]
                self.counts[state][step.action] += 1

                print(f"Step {i}: Updated utility for (state={state}, action={step.action}) to {self.sum_utilities[state][step.action]}. Count is now {self.counts[state][step.action]}.")

            # Display the updated Q-values
            print("Updated Q-values after episode:")
            for s in self.sum_utilities.keys():
                for a in self.sum_utilities[s].keys():
                    q_value = self.Q(s, a)
                    print(f"Q({s}, {a}) = {q_value} (sum_utilities={self.sum_utilities[s][a]}, count={self.counts[s][a]})")

            # Reset history
            self.start_state = None
            self.rollout = []

# %%
exploration_policy = partial(walk_tram_policy, mdp.num_locs)
rl = ModelFreeMonteCarlo(exploration_policy=exploration_policy, epsilon=0.4, discount=1)

# %%
value = simulate(mdp, rl, num_trials=20)
leaderboard = update_leaderboard("model_free_monte_carlo", value)
# Out:
# State 1: Choosing random action tram (initial exploration)
# Incorporating feedback: state=1, action=tram, reward=-2, next_state=2, is_end=False
# State 2: Choosing random action walk (initial exploration)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing random action walk (initial exploration)
# Incorporating feedback: state=3, action=walk, reward=-1, next_state=4, is_end=False
# State 4: Choosing random action tram (initial exploration)
# Incorporating feedback: state=4, action=tram, reward=-2, next_state=8, is_end=False
# State 8: Choosing random action walk (initial exploration)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing random action walk (initial exploration)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 5: Updated utility for (state=9, action=walk) to -1.0. Count is now 1.
# Step 4: Updated utility for (state=8, action=walk) to -2.0. Count is now 1.
# Step 3: Updated utility for (state=4, action=tram) to -4.0. Count is now 1.
# Step 2: Updated utility for (state=3, action=walk) to -5.0. Count is now 1.
# Step 1: Updated utility for (state=2, action=walk) to -6.0. Count is now 1.
# Step 0: Updated utility for (state=1, action=tram) to -8.0. Count is now 1.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-1.0, count=1)
# Q(8, walk) = -2.0 (sum_utilities=-2.0, count=1)
# Q(4, tram) = -4.0 (sum_utilities=-4.0, count=1)
# Q(3, walk) = -5.0 (sum_utilities=-5.0, count=1)
# Q(2, walk) = -6.0 (sum_utilities=-6.0, count=1)
# Q(1, tram) = -8.0 (sum_utilities=-8.0, count=1)
# State 1: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=1, action=tram, reward=-2, next_state=2, is_end=False
# State 2: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=2, action=tram, reward=-2, next_state=4, is_end=False
# State 4: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=4, action=tram, reward=-2, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 4: Updated utility for (state=9, action=walk) to -2.0. Count is now 2.
# Step 3: Updated utility for (state=8, action=walk) to -4.0. Count is now 2.
# Step 2: Updated utility for (state=4, action=tram) to -8.0. Count is now 2.
# Step 1: Updated utility for (state=2, action=tram) to -6.0. Count is now 1.
# Step 0: Updated utility for (state=1, action=tram) to -16.0. Count is now 2.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-2.0, count=2)
# Q(8, walk) = -2.0 (sum_utilities=-4.0, count=2)
# Q(4, tram) = -4.0 (sum_utilities=-8.0, count=2)
# Q(3, walk) = -5.0 (sum_utilities=-5.0, count=1)
# Q(2, walk) = -6.0 (sum_utilities=-6.0, count=1)
# Q(2, tram) = -6.0 (sum_utilities=-6.0, count=1)
# Q(1, tram) = -8.0 (sum_utilities=-16.0, count=2)
# State 1: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=3, action=walk, reward=-1, next_state=4, is_end=False
# State 4: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=4, action=walk, reward=-1, next_state=5, is_end=False
# State 5: Choosing random action walk (initial exploration)
# Incorporating feedback: state=5, action=walk, reward=-1, next_state=6, is_end=False
# State 6: Choosing random action walk (initial exploration)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing random action walk (initial exploration)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 8: Updated utility for (state=9, action=walk) to -3.0. Count is now 3.
# Step 7: Updated utility for (state=8, action=walk) to -6.0. Count is now 3.
# Step 6: Updated utility for (state=7, action=walk) to -3.0. Count is now 1.
# Step 5: Updated utility for (state=6, action=walk) to -4.0. Count is now 1.
# Step 4: Updated utility for (state=5, action=walk) to -5.0. Count is now 1.
# Step 3: Updated utility for (state=4, action=walk) to -6.0. Count is now 1.
# Step 2: Updated utility for (state=3, action=walk) to -12.0. Count is now 2.
# Step 1: Updated utility for (state=2, action=walk) to -14.0. Count is now 2.
# Step 0: Updated utility for (state=1, action=walk) to -9.0. Count is now 1.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-3.0, count=3)
# Q(8, walk) = -2.0 (sum_utilities=-6.0, count=3)
# Q(4, tram) = -4.0 (sum_utilities=-8.0, count=2)
# Q(4, walk) = -6.0 (sum_utilities=-6.0, count=1)
# Q(3, walk) = -6.0 (sum_utilities=-12.0, count=2)
# Q(2, walk) = -7.0 (sum_utilities=-14.0, count=2)
# Q(2, tram) = -6.0 (sum_utilities=-6.0, count=1)
# Q(1, tram) = -8.0 (sum_utilities=-16.0, count=2)
# Q(1, walk) = -9.0 (sum_utilities=-9.0, count=1)
# Q(7, walk) = -3.0 (sum_utilities=-3.0, count=1)
# Q(6, walk) = -4.0 (sum_utilities=-4.0, count=1)
# Q(5, walk) = -5.0 (sum_utilities=-5.0, count=1)
# State 1: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=1, action=tram, reward=-2, next_state=1, is_end=False
# State 1: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=2, action=tram, reward=-2, next_state=2, is_end=False
# State 2: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=2, action=tram, reward=-2, next_state=4, is_end=False
# State 4: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=4, action=walk, reward=-1, next_state=5, is_end=False
# State 5: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=5, action=walk, reward=-1, next_state=6, is_end=False
# State 6: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 9: Updated utility for (state=9, action=walk) to -4.0. Count is now 4.
# Step 8: Updated utility for (state=8, action=walk) to -8.0. Count is now 4.
# Step 7: Updated utility for (state=7, action=walk) to -6.0. Count is now 2.
# Step 6: Updated utility for (state=6, action=walk) to -8.0. Count is now 2.
# Step 5: Updated utility for (state=5, action=walk) to -10.0. Count is now 2.
# Step 4: Updated utility for (state=4, action=walk) to -12.0. Count is now 2.
# Step 3: Updated utility for (state=2, action=tram) to -14.0. Count is now 2.
# Step 2: Updated utility for (state=2, action=tram) to -24.0. Count is now 3.
# Step 1: Updated utility for (state=1, action=walk) to -20.0. Count is now 2.
# Step 0: Updated utility for (state=1, action=tram) to -29.0. Count is now 3.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-4.0, count=4)
# Q(8, walk) = -2.0 (sum_utilities=-8.0, count=4)
# Q(4, tram) = -4.0 (sum_utilities=-8.0, count=2)
# Q(4, walk) = -6.0 (sum_utilities=-12.0, count=2)
# Q(3, walk) = -6.0 (sum_utilities=-12.0, count=2)
# Q(2, walk) = -7.0 (sum_utilities=-14.0, count=2)
# Q(2, tram) = -8.0 (sum_utilities=-24.0, count=3)
# Q(1, tram) = -9.666666666666666 (sum_utilities=-29.0, count=3)
# Q(1, walk) = -10.0 (sum_utilities=-20.0, count=2)
# Q(7, walk) = -3.0 (sum_utilities=-6.0, count=2)
# Q(6, walk) = -4.0 (sum_utilities=-8.0, count=2)
# Q(5, walk) = -5.0 (sum_utilities=-10.0, count=2)
# State 1: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=1, action=tram, reward=-2, next_state=1, is_end=False
# State 1: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=1, action=tram, reward=-2, next_state=1, is_end=False
# State 1: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=1, action=tram, reward=-2, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=3, action=walk, reward=-1, next_state=4, is_end=False
# State 4: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=4, action=tram, reward=-2, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 7: Updated utility for (state=9, action=walk) to -5.0. Count is now 5.
# Step 6: Updated utility for (state=8, action=walk) to -10.0. Count is now 5.
# Step 5: Updated utility for (state=4, action=tram) to -12.0. Count is now 3.
# Step 4: Updated utility for (state=3, action=walk) to -17.0. Count is now 3.
# Step 3: Updated utility for (state=2, action=walk) to -20.0. Count is now 3.
# Step 2: Updated utility for (state=1, action=tram) to -37.0. Count is now 4.
# Step 1: Updated utility for (state=1, action=tram) to -47.0. Count is now 5.
# Step 0: Updated utility for (state=1, action=tram) to -59.0. Count is now 6.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-5.0, count=5)
# Q(8, walk) = -2.0 (sum_utilities=-10.0, count=5)
# Q(4, tram) = -4.0 (sum_utilities=-12.0, count=3)
# Q(4, walk) = -6.0 (sum_utilities=-12.0, count=2)
# Q(3, walk) = -5.666666666666667 (sum_utilities=-17.0, count=3)
# Q(2, walk) = -6.666666666666667 (sum_utilities=-20.0, count=3)
# Q(2, tram) = -8.0 (sum_utilities=-24.0, count=3)
# Q(1, tram) = -9.833333333333334 (sum_utilities=-59.0, count=6)
# Q(1, walk) = -10.0 (sum_utilities=-20.0, count=2)
# Q(7, walk) = -3.0 (sum_utilities=-6.0, count=2)
# Q(6, walk) = -4.0 (sum_utilities=-8.0, count=2)
# Q(5, walk) = -5.0 (sum_utilities=-10.0, count=2)
# State 1: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=1, action=tram, reward=-2, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=3, action=walk, reward=-1, next_state=4, is_end=False
# State 4: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=4, action=tram, reward=-2, next_state=4, is_end=False
# State 4: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=4, action=tram, reward=-2, next_state=4, is_end=False
# State 4: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=4, action=walk, reward=-1, next_state=5, is_end=False
# State 5: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=5, action=walk, reward=-1, next_state=6, is_end=False
# State 6: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 10: Updated utility for (state=9, action=walk) to -6.0. Count is now 6.
# Step 9: Updated utility for (state=8, action=walk) to -12.0. Count is now 6.
# Step 8: Updated utility for (state=7, action=walk) to -9.0. Count is now 3.
# Step 7: Updated utility for (state=6, action=walk) to -12.0. Count is now 3.
# Step 6: Updated utility for (state=5, action=walk) to -15.0. Count is now 3.
# Step 5: Updated utility for (state=4, action=walk) to -18.0. Count is now 3.
# Step 4: Updated utility for (state=4, action=tram) to -20.0. Count is now 4.
# Step 3: Updated utility for (state=4, action=tram) to -30.0. Count is now 5.
# Step 2: Updated utility for (state=3, action=walk) to -28.0. Count is now 4.
# Step 1: Updated utility for (state=2, action=walk) to -32.0. Count is now 4.
# Step 0: Updated utility for (state=1, action=tram) to -73.0. Count is now 7.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-6.0, count=6)
# Q(8, walk) = -2.0 (sum_utilities=-12.0, count=6)
# Q(4, tram) = -6.0 (sum_utilities=-30.0, count=5)
# Q(4, walk) = -6.0 (sum_utilities=-18.0, count=3)
# Q(3, walk) = -7.0 (sum_utilities=-28.0, count=4)
# Q(2, walk) = -8.0 (sum_utilities=-32.0, count=4)
# Q(2, tram) = -8.0 (sum_utilities=-24.0, count=3)
# Q(1, tram) = -10.428571428571429 (sum_utilities=-73.0, count=7)
# Q(1, walk) = -10.0 (sum_utilities=-20.0, count=2)
# Q(7, walk) = -3.0 (sum_utilities=-9.0, count=3)
# Q(6, walk) = -4.0 (sum_utilities=-12.0, count=3)
# Q(5, walk) = -5.0 (sum_utilities=-15.0, count=3)
# State 1: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=3, action=walk, reward=-1, next_state=4, is_end=False
# State 4: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=4, action=walk, reward=-1, next_state=5, is_end=False
# State 5: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=5, action=walk, reward=-1, next_state=6, is_end=False
# State 6: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 8: Updated utility for (state=9, action=walk) to -7.0. Count is now 7.
# Step 7: Updated utility for (state=8, action=walk) to -14.0. Count is now 7.
# Step 6: Updated utility for (state=7, action=walk) to -12.0. Count is now 4.
# Step 5: Updated utility for (state=6, action=walk) to -16.0. Count is now 4.
# Step 4: Updated utility for (state=5, action=walk) to -20.0. Count is now 4.
# Step 3: Updated utility for (state=4, action=walk) to -24.0. Count is now 4.
# Step 2: Updated utility for (state=3, action=walk) to -35.0. Count is now 5.
# Step 1: Updated utility for (state=2, action=walk) to -40.0. Count is now 5.
# Step 0: Updated utility for (state=1, action=walk) to -29.0. Count is now 3.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-7.0, count=7)
# Q(8, walk) = -2.0 (sum_utilities=-14.0, count=7)
# Q(4, tram) = -6.0 (sum_utilities=-30.0, count=5)
# Q(4, walk) = -6.0 (sum_utilities=-24.0, count=4)
# Q(3, walk) = -7.0 (sum_utilities=-35.0, count=5)
# Q(2, walk) = -8.0 (sum_utilities=-40.0, count=5)
# Q(2, tram) = -8.0 (sum_utilities=-24.0, count=3)
# Q(1, tram) = -10.428571428571429 (sum_utilities=-73.0, count=7)
# Q(1, walk) = -9.666666666666666 (sum_utilities=-29.0, count=3)
# Q(7, walk) = -3.0 (sum_utilities=-12.0, count=4)
# Q(6, walk) = -4.0 (sum_utilities=-16.0, count=4)
# Q(5, walk) = -5.0 (sum_utilities=-20.0, count=4)
# State 1: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=3, action=walk, reward=-1, next_state=4, is_end=False
# State 4: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=4, action=walk, reward=-1, next_state=5, is_end=False
# State 5: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=5, action=walk, reward=-1, next_state=6, is_end=False
# State 6: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 8: Updated utility for (state=9, action=walk) to -8.0. Count is now 8.
# Step 7: Updated utility for (state=8, action=walk) to -16.0. Count is now 8.
# Step 6: Updated utility for (state=7, action=walk) to -15.0. Count is now 5.
# Step 5: Updated utility for (state=6, action=walk) to -20.0. Count is now 5.
# Step 4: Updated utility for (state=5, action=walk) to -25.0. Count is now 5.
# Step 3: Updated utility for (state=4, action=walk) to -30.0. Count is now 5.
# Step 2: Updated utility for (state=3, action=walk) to -42.0. Count is now 6.
# Step 1: Updated utility for (state=2, action=walk) to -48.0. Count is now 6.
# Step 0: Updated utility for (state=1, action=walk) to -38.0. Count is now 4.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-8.0, count=8)
# Q(8, walk) = -2.0 (sum_utilities=-16.0, count=8)
# Q(4, tram) = -6.0 (sum_utilities=-30.0, count=5)
# Q(4, walk) = -6.0 (sum_utilities=-30.0, count=5)
# Q(3, walk) = -7.0 (sum_utilities=-42.0, count=6)
# Q(2, walk) = -8.0 (sum_utilities=-48.0, count=6)
# Q(2, tram) = -8.0 (sum_utilities=-24.0, count=3)
# Q(1, tram) = -10.428571428571429 (sum_utilities=-73.0, count=7)
# Q(1, walk) = -9.5 (sum_utilities=-38.0, count=4)
# Q(7, walk) = -3.0 (sum_utilities=-15.0, count=5)
# Q(6, walk) = -4.0 (sum_utilities=-20.0, count=5)
# Q(5, walk) = -5.0 (sum_utilities=-25.0, count=5)
# State 1: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=3, action=walk, reward=-1, next_state=4, is_end=False
# State 4: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=4, action=walk, reward=-1, next_state=5, is_end=False
# State 5: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=5, action=tram, reward=-2, next_state=5, is_end=False
# State 5: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=5, action=walk, reward=-1, next_state=6, is_end=False
# State 6: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 9: Updated utility for (state=9, action=walk) to -9.0. Count is now 9.
# Step 8: Updated utility for (state=8, action=walk) to -18.0. Count is now 9.
# Step 7: Updated utility for (state=7, action=walk) to -18.0. Count is now 6.
# Step 6: Updated utility for (state=6, action=walk) to -24.0. Count is now 6.
# Step 5: Updated utility for (state=5, action=walk) to -30.0. Count is now 6.
# Step 4: Updated utility for (state=5, action=tram) to -7.0. Count is now 1.
# Step 3: Updated utility for (state=4, action=walk) to -38.0. Count is now 6.
# Step 2: Updated utility for (state=3, action=walk) to -51.0. Count is now 7.
# Step 1: Updated utility for (state=2, action=walk) to -58.0. Count is now 7.
# Step 0: Updated utility for (state=1, action=walk) to -49.0. Count is now 5.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-9.0, count=9)
# Q(8, walk) = -2.0 (sum_utilities=-18.0, count=9)
# Q(4, tram) = -6.0 (sum_utilities=-30.0, count=5)
# Q(4, walk) = -6.333333333333333 (sum_utilities=-38.0, count=6)
# Q(3, walk) = -7.285714285714286 (sum_utilities=-51.0, count=7)
# Q(2, walk) = -8.285714285714286 (sum_utilities=-58.0, count=7)
# Q(2, tram) = -8.0 (sum_utilities=-24.0, count=3)
# Q(1, tram) = -10.428571428571429 (sum_utilities=-73.0, count=7)
# Q(1, walk) = -9.8 (sum_utilities=-49.0, count=5)
# Q(7, walk) = -3.0 (sum_utilities=-18.0, count=6)
# Q(6, walk) = -4.0 (sum_utilities=-24.0, count=6)
# Q(5, walk) = -5.0 (sum_utilities=-30.0, count=6)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=2, action=tram, reward=-2, next_state=2, is_end=False
# State 2: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=2, action=tram, reward=-2, next_state=2, is_end=False
# State 2: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=3, action=walk, reward=-1, next_state=4, is_end=False
# State 4: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=4, action=tram, reward=-2, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 7: Updated utility for (state=9, action=walk) to -10.0. Count is now 10.
# Step 6: Updated utility for (state=8, action=walk) to -20.0. Count is now 10.
# Step 5: Updated utility for (state=4, action=tram) to -34.0. Count is now 6.
# Step 4: Updated utility for (state=3, action=walk) to -56.0. Count is now 8.
# Step 3: Updated utility for (state=2, action=walk) to -64.0. Count is now 8.
# Step 2: Updated utility for (state=2, action=tram) to -32.0. Count is now 4.
# Step 1: Updated utility for (state=2, action=tram) to -42.0. Count is now 5.
# Step 0: Updated utility for (state=1, action=walk) to -60.0. Count is now 6.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-10.0, count=10)
# Q(8, walk) = -2.0 (sum_utilities=-20.0, count=10)
# Q(4, tram) = -5.666666666666667 (sum_utilities=-34.0, count=6)
# Q(4, walk) = -6.333333333333333 (sum_utilities=-38.0, count=6)
# Q(3, walk) = -7.0 (sum_utilities=-56.0, count=8)
# Q(2, walk) = -8.0 (sum_utilities=-64.0, count=8)
# Q(2, tram) = -8.4 (sum_utilities=-42.0, count=5)
# Q(1, tram) = -10.428571428571429 (sum_utilities=-73.0, count=7)
# Q(1, walk) = -10.0 (sum_utilities=-60.0, count=6)
# Q(7, walk) = -3.0 (sum_utilities=-18.0, count=6)
# Q(6, walk) = -4.0 (sum_utilities=-24.0, count=6)
# Q(5, walk) = -5.0 (sum_utilities=-30.0, count=6)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=6, is_end=False
# State 6: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 6: Updated utility for (state=9, action=walk) to -11.0. Count is now 11.
# Step 5: Updated utility for (state=8, action=walk) to -22.0. Count is now 11.
# Step 4: Updated utility for (state=7, action=walk) to -21.0. Count is now 7.
# Step 3: Updated utility for (state=6, action=walk) to -28.0. Count is now 7.
# Step 2: Updated utility for (state=3, action=tram) to -6.0. Count is now 1.
# Step 1: Updated utility for (state=2, action=walk) to -71.0. Count is now 9.
# Step 0: Updated utility for (state=1, action=walk) to -68.0. Count is now 7.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-11.0, count=11)
# Q(8, walk) = -2.0 (sum_utilities=-22.0, count=11)
# Q(4, tram) = -5.666666666666667 (sum_utilities=-34.0, count=6)
# Q(4, walk) = -6.333333333333333 (sum_utilities=-38.0, count=6)
# Q(3, walk) = -7.0 (sum_utilities=-56.0, count=8)
# Q(3, tram) = -6.0 (sum_utilities=-6.0, count=1)
# Q(2, walk) = -7.888888888888889 (sum_utilities=-71.0, count=9)
# Q(2, tram) = -8.4 (sum_utilities=-42.0, count=5)
# Q(1, tram) = -10.428571428571429 (sum_utilities=-73.0, count=7)
# Q(1, walk) = -9.714285714285714 (sum_utilities=-68.0, count=7)
# Q(7, walk) = -3.0 (sum_utilities=-21.0, count=7)
# Q(6, walk) = -4.0 (sum_utilities=-28.0, count=7)
# Q(5, walk) = -5.0 (sum_utilities=-30.0, count=6)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=1, action=tram, reward=-2, next_state=1, is_end=False
# State 1: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=3, is_end=False
# State 3: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=6, is_end=False
# State 6: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 8: Updated utility for (state=9, action=walk) to -12.0. Count is now 12.
# Step 7: Updated utility for (state=8, action=walk) to -24.0. Count is now 12.
# Step 6: Updated utility for (state=7, action=walk) to -24.0. Count is now 8.
# Step 5: Updated utility for (state=6, action=walk) to -32.0. Count is now 8.
# Step 4: Updated utility for (state=3, action=tram) to -12.0. Count is now 2.
# Step 3: Updated utility for (state=3, action=tram) to -20.0. Count is now 3.
# Step 2: Updated utility for (state=2, action=walk) to -80.0. Count is now 10.
# Step 1: Updated utility for (state=1, action=walk) to -78.0. Count is now 8.
# Step 0: Updated utility for (state=1, action=tram) to -85.0. Count is now 8.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-12.0, count=12)
# Q(8, walk) = -2.0 (sum_utilities=-24.0, count=12)
# Q(4, tram) = -5.666666666666667 (sum_utilities=-34.0, count=6)
# Q(4, walk) = -6.333333333333333 (sum_utilities=-38.0, count=6)
# Q(3, walk) = -7.0 (sum_utilities=-56.0, count=8)
# Q(3, tram) = -6.666666666666667 (sum_utilities=-20.0, count=3)
# Q(2, walk) = -8.0 (sum_utilities=-80.0, count=10)
# Q(2, tram) = -8.4 (sum_utilities=-42.0, count=5)
# Q(1, tram) = -10.625 (sum_utilities=-85.0, count=8)
# Q(1, walk) = -9.75 (sum_utilities=-78.0, count=8)
# Q(7, walk) = -3.0 (sum_utilities=-24.0, count=8)
# Q(6, walk) = -4.0 (sum_utilities=-32.0, count=8)
# Q(5, walk) = -5.0 (sum_utilities=-30.0, count=6)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=6, is_end=False
# State 6: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 6: Updated utility for (state=9, action=walk) to -13.0. Count is now 13.
# Step 5: Updated utility for (state=8, action=walk) to -26.0. Count is now 13.
# Step 4: Updated utility for (state=7, action=walk) to -27.0. Count is now 9.
# Step 3: Updated utility for (state=6, action=walk) to -36.0. Count is now 9.
# Step 2: Updated utility for (state=3, action=tram) to -26.0. Count is now 4.
# Step 1: Updated utility for (state=2, action=walk) to -87.0. Count is now 11.
# Step 0: Updated utility for (state=1, action=walk) to -86.0. Count is now 9.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-13.0, count=13)
# Q(8, walk) = -2.0 (sum_utilities=-26.0, count=13)
# Q(4, tram) = -5.666666666666667 (sum_utilities=-34.0, count=6)
# Q(4, walk) = -6.333333333333333 (sum_utilities=-38.0, count=6)
# Q(3, walk) = -7.0 (sum_utilities=-56.0, count=8)
# Q(3, tram) = -6.5 (sum_utilities=-26.0, count=4)
# Q(2, walk) = -7.909090909090909 (sum_utilities=-87.0, count=11)
# Q(2, tram) = -8.4 (sum_utilities=-42.0, count=5)
# Q(1, tram) = -10.625 (sum_utilities=-85.0, count=8)
# Q(1, walk) = -9.555555555555555 (sum_utilities=-86.0, count=9)
# Q(7, walk) = -3.0 (sum_utilities=-27.0, count=9)
# Q(6, walk) = -4.0 (sum_utilities=-36.0, count=9)
# Q(5, walk) = -5.0 (sum_utilities=-30.0, count=6)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=6, is_end=False
# State 6: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 6: Updated utility for (state=9, action=walk) to -14.0. Count is now 14.
# Step 5: Updated utility for (state=8, action=walk) to -28.0. Count is now 14.
# Step 4: Updated utility for (state=7, action=walk) to -30.0. Count is now 10.
# Step 3: Updated utility for (state=6, action=walk) to -40.0. Count is now 10.
# Step 2: Updated utility for (state=3, action=tram) to -32.0. Count is now 5.
# Step 1: Updated utility for (state=2, action=walk) to -94.0. Count is now 12.
# Step 0: Updated utility for (state=1, action=walk) to -94.0. Count is now 10.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-14.0, count=14)
# Q(8, walk) = -2.0 (sum_utilities=-28.0, count=14)
# Q(4, tram) = -5.666666666666667 (sum_utilities=-34.0, count=6)
# Q(4, walk) = -6.333333333333333 (sum_utilities=-38.0, count=6)
# Q(3, walk) = -7.0 (sum_utilities=-56.0, count=8)
# Q(3, tram) = -6.4 (sum_utilities=-32.0, count=5)
# Q(2, walk) = -7.833333333333333 (sum_utilities=-94.0, count=12)
# Q(2, tram) = -8.4 (sum_utilities=-42.0, count=5)
# Q(1, tram) = -10.625 (sum_utilities=-85.0, count=8)
# Q(1, walk) = -9.4 (sum_utilities=-94.0, count=10)
# Q(7, walk) = -3.0 (sum_utilities=-30.0, count=10)
# Q(6, walk) = -4.0 (sum_utilities=-40.0, count=10)
# Q(5, walk) = -5.0 (sum_utilities=-30.0, count=6)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=2, action=tram, reward=-2, next_state=4, is_end=False
# State 4: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=4, action=walk, reward=-1, next_state=5, is_end=False
# State 5: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=5, action=walk, reward=-1, next_state=6, is_end=False
# State 6: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 7: Updated utility for (state=9, action=walk) to -15.0. Count is now 15.
# Step 6: Updated utility for (state=8, action=walk) to -30.0. Count is now 15.
# Step 5: Updated utility for (state=7, action=walk) to -33.0. Count is now 11.
# Step 4: Updated utility for (state=6, action=walk) to -44.0. Count is now 11.
# Step 3: Updated utility for (state=5, action=walk) to -35.0. Count is now 7.
# Step 2: Updated utility for (state=4, action=walk) to -44.0. Count is now 7.
# Step 1: Updated utility for (state=2, action=tram) to -50.0. Count is now 6.
# Step 0: Updated utility for (state=1, action=walk) to -103.0. Count is now 11.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-15.0, count=15)
# Q(8, walk) = -2.0 (sum_utilities=-30.0, count=15)
# Q(4, tram) = -5.666666666666667 (sum_utilities=-34.0, count=6)
# Q(4, walk) = -6.285714285714286 (sum_utilities=-44.0, count=7)
# Q(3, walk) = -7.0 (sum_utilities=-56.0, count=8)
# Q(3, tram) = -6.4 (sum_utilities=-32.0, count=5)
# Q(2, walk) = -7.833333333333333 (sum_utilities=-94.0, count=12)
# Q(2, tram) = -8.333333333333334 (sum_utilities=-50.0, count=6)
# Q(1, tram) = -10.625 (sum_utilities=-85.0, count=8)
# Q(1, walk) = -9.363636363636363 (sum_utilities=-103.0, count=11)
# Q(7, walk) = -3.0 (sum_utilities=-33.0, count=11)
# Q(6, walk) = -4.0 (sum_utilities=-44.0, count=11)
# Q(5, walk) = -5.0 (sum_utilities=-35.0, count=7)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=3, is_end=False
# State 3: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=3, action=walk, reward=-1, next_state=4, is_end=False
# State 4: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=4, action=walk, reward=-1, next_state=5, is_end=False
# State 5: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=5, action=walk, reward=-1, next_state=6, is_end=False
# State 6: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 9: Updated utility for (state=9, action=walk) to -16.0. Count is now 16.
# Step 8: Updated utility for (state=8, action=walk) to -32.0. Count is now 16.
# Step 7: Updated utility for (state=7, action=walk) to -36.0. Count is now 12.
# Step 6: Updated utility for (state=6, action=walk) to -48.0. Count is now 12.
# Step 5: Updated utility for (state=5, action=walk) to -40.0. Count is now 8.
# Step 4: Updated utility for (state=4, action=walk) to -50.0. Count is now 8.
# Step 3: Updated utility for (state=3, action=walk) to -63.0. Count is now 9.
# Step 2: Updated utility for (state=3, action=tram) to -41.0. Count is now 6.
# Step 1: Updated utility for (state=2, action=walk) to -104.0. Count is now 13.
# Step 0: Updated utility for (state=1, action=walk) to -114.0. Count is now 12.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-16.0, count=16)
# Q(8, walk) = -2.0 (sum_utilities=-32.0, count=16)
# Q(4, tram) = -5.666666666666667 (sum_utilities=-34.0, count=6)
# Q(4, walk) = -6.25 (sum_utilities=-50.0, count=8)
# Q(3, walk) = -7.0 (sum_utilities=-63.0, count=9)
# Q(3, tram) = -6.833333333333333 (sum_utilities=-41.0, count=6)
# Q(2, walk) = -8.0 (sum_utilities=-104.0, count=13)
# Q(2, tram) = -8.333333333333334 (sum_utilities=-50.0, count=6)
# Q(1, tram) = -10.625 (sum_utilities=-85.0, count=8)
# Q(1, walk) = -9.5 (sum_utilities=-114.0, count=12)
# Q(7, walk) = -3.0 (sum_utilities=-36.0, count=12)
# Q(6, walk) = -4.0 (sum_utilities=-48.0, count=12)
# Q(5, walk) = -5.0 (sum_utilities=-40.0, count=8)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=2, action=tram, reward=-2, next_state=4, is_end=False
# State 4: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=4, action=tram, reward=-2, next_state=4, is_end=False
# State 4: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=4, action=tram, reward=-2, next_state=4, is_end=False
# State 4: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=4, action=tram, reward=-2, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 6: Updated utility for (state=9, action=walk) to -17.0. Count is now 17.
# Step 5: Updated utility for (state=8, action=walk) to -34.0. Count is now 17.
# Step 4: Updated utility for (state=4, action=tram) to -38.0. Count is now 7.
# Step 3: Updated utility for (state=4, action=tram) to -44.0. Count is now 8.
# Step 2: Updated utility for (state=4, action=tram) to -52.0. Count is now 9.
# Step 1: Updated utility for (state=2, action=tram) to -60.0. Count is now 7.
# Step 0: Updated utility for (state=1, action=walk) to -125.0. Count is now 13.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-17.0, count=17)
# Q(8, walk) = -2.0 (sum_utilities=-34.0, count=17)
# Q(4, tram) = -5.777777777777778 (sum_utilities=-52.0, count=9)
# Q(4, walk) = -6.25 (sum_utilities=-50.0, count=8)
# Q(3, walk) = -7.0 (sum_utilities=-63.0, count=9)
# Q(3, tram) = -6.833333333333333 (sum_utilities=-41.0, count=6)
# Q(2, walk) = -8.0 (sum_utilities=-104.0, count=13)
# Q(2, tram) = -8.571428571428571 (sum_utilities=-60.0, count=7)
# Q(1, tram) = -10.625 (sum_utilities=-85.0, count=8)
# Q(1, walk) = -9.615384615384615 (sum_utilities=-125.0, count=13)
# Q(7, walk) = -3.0 (sum_utilities=-36.0, count=12)
# Q(6, walk) = -4.0 (sum_utilities=-48.0, count=12)
# Q(5, walk) = -5.0 (sum_utilities=-40.0, count=8)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=1, action=tram, reward=-2, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing random action tram (epsilon-greedy)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=6, is_end=False
# State 6: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 6: Updated utility for (state=9, action=walk) to -18.0. Count is now 18.
# Step 5: Updated utility for (state=8, action=walk) to -36.0. Count is now 18.
# Step 4: Updated utility for (state=7, action=walk) to -39.0. Count is now 13.
# Step 3: Updated utility for (state=6, action=walk) to -52.0. Count is now 13.
# Step 2: Updated utility for (state=3, action=tram) to -47.0. Count is now 7.
# Step 1: Updated utility for (state=2, action=walk) to -111.0. Count is now 14.
# Step 0: Updated utility for (state=1, action=tram) to -94.0. Count is now 9.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-18.0, count=18)
# Q(8, walk) = -2.0 (sum_utilities=-36.0, count=18)
# Q(4, tram) = -5.777777777777778 (sum_utilities=-52.0, count=9)
# Q(4, walk) = -6.25 (sum_utilities=-50.0, count=8)
# Q(3, walk) = -7.0 (sum_utilities=-63.0, count=9)
# Q(3, tram) = -6.714285714285714 (sum_utilities=-47.0, count=7)
# Q(2, walk) = -7.928571428571429 (sum_utilities=-111.0, count=14)
# Q(2, tram) = -8.571428571428571 (sum_utilities=-60.0, count=7)
# Q(1, tram) = -10.444444444444445 (sum_utilities=-94.0, count=9)
# Q(1, walk) = -9.615384615384615 (sum_utilities=-125.0, count=13)
# Q(7, walk) = -3.0 (sum_utilities=-39.0, count=13)
# Q(6, walk) = -4.0 (sum_utilities=-52.0, count=13)
# Q(5, walk) = -5.0 (sum_utilities=-40.0, count=8)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=3, is_end=False
# State 3: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=6, is_end=False
# State 6: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 7: Updated utility for (state=9, action=walk) to -19.0. Count is now 19.
# Step 6: Updated utility for (state=8, action=walk) to -38.0. Count is now 19.
# Step 5: Updated utility for (state=7, action=walk) to -42.0. Count is now 14.
# Step 4: Updated utility for (state=6, action=walk) to -56.0. Count is now 14.
# Step 3: Updated utility for (state=3, action=tram) to -53.0. Count is now 8.
# Step 2: Updated utility for (state=3, action=tram) to -61.0. Count is now 9.
# Step 1: Updated utility for (state=2, action=walk) to -120.0. Count is now 15.
# Step 0: Updated utility for (state=1, action=walk) to -135.0. Count is now 14.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-19.0, count=19)
# Q(8, walk) = -2.0 (sum_utilities=-38.0, count=19)
# Q(4, tram) = -5.777777777777778 (sum_utilities=-52.0, count=9)
# Q(4, walk) = -6.25 (sum_utilities=-50.0, count=8)
# Q(3, walk) = -7.0 (sum_utilities=-63.0, count=9)
# Q(3, tram) = -6.777777777777778 (sum_utilities=-61.0, count=9)
# Q(2, walk) = -8.0 (sum_utilities=-120.0, count=15)
# Q(2, tram) = -8.571428571428571 (sum_utilities=-60.0, count=7)
# Q(1, tram) = -10.444444444444445 (sum_utilities=-94.0, count=9)
# Q(1, walk) = -9.642857142857142 (sum_utilities=-135.0, count=14)
# Q(7, walk) = -3.0 (sum_utilities=-42.0, count=14)
# Q(6, walk) = -4.0 (sum_utilities=-56.0, count=14)
# Q(5, walk) = -5.0 (sum_utilities=-40.0, count=8)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
# State 1: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=1, action=walk, reward=-1, next_state=2, is_end=False
# State 2: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=2, action=walk, reward=-1, next_state=3, is_end=False
# State 3: Choosing best action tram (based on Q-values)
# Incorporating feedback: state=3, action=tram, reward=-2, next_state=6, is_end=False
# State 6: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=6, action=walk, reward=-1, next_state=7, is_end=False
# State 7: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=7, action=walk, reward=-1, next_state=8, is_end=False
# State 8: Choosing random action walk (epsilon-greedy)
# Incorporating feedback: state=8, action=walk, reward=-1, next_state=9, is_end=False
# State 9: Choosing best action walk (based on Q-values)
# Incorporating feedback: state=9, action=walk, reward=-1, next_state=10, is_end=True
# End of episode reached.
# Step 6: Updated utility for (state=9, action=walk) to -20.0. Count is now 20.
# Step 5: Updated utility for (state=8, action=walk) to -40.0. Count is now 20.
# Step 4: Updated utility for (state=7, action=walk) to -45.0. Count is now 15.
# Step 3: Updated utility for (state=6, action=walk) to -60.0. Count is now 15.
# Step 2: Updated utility for (state=3, action=tram) to -67.0. Count is now 10.
# Step 1: Updated utility for (state=2, action=walk) to -127.0. Count is now 16.
# Step 0: Updated utility for (state=1, action=walk) to -143.0. Count is now 15.
# Updated Q-values after episode:
# Q(9, walk) = -1.0 (sum_utilities=-20.0, count=20)
# Q(8, walk) = -2.0 (sum_utilities=-40.0, count=20)
# Q(4, tram) = -5.777777777777778 (sum_utilities=-52.0, count=9)
# Q(4, walk) = -6.25 (sum_utilities=-50.0, count=8)
# Q(3, walk) = -7.0 (sum_utilities=-63.0, count=9)
# Q(3, tram) = -6.7 (sum_utilities=-67.0, count=10)
# Q(2, walk) = -7.9375 (sum_utilities=-127.0, count=16)
# Q(2, tram) = -8.571428571428571 (sum_utilities=-60.0, count=7)
# Q(1, tram) = -10.444444444444445 (sum_utilities=-94.0, count=9)
# Q(1, walk) = -9.533333333333333 (sum_utilities=-143.0, count=15)
# Q(7, walk) = -3.0 (sum_utilities=-45.0, count=15)
# Q(6, walk) = -4.0 (sum_utilities=-60.0, count=15)
# Q(5, walk) = -5.0 (sum_utilities=-40.0, count=8)
# Q(5, tram) = -7.0 (sum_utilities=-7.0, count=1)
